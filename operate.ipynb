# %%
import open3d as o3d
from helchriss.benchmarks.vqa.shapes3 import Shapes3Dataset
from helchriss.utils import stprint

train_dataset = Shapes3Dataset(dataset_size=1024)  # create a dataset with 1024 samples
test_dataset = Shapes3Dataset(dataset_size=128)  # create a dataset with 128 samples for testing

# Now let's visualize a few samples from the dataset:
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 4))
for i in range(6):
    plt.subplot(2, 3, i + 1)
    plt.imshow(train_dataset[i]['image'].permute(1, 2, 0).numpy()[..., ::-1] * 0.5 + 0.5)
    plt.title(train_dataset[i]['question'] + ': ' + str(train_dataset[i]['answer']))
    stprint(train_dataset[i])
plt.tight_layout()
plt.show()
# Out:
# train_dataset[i] = dict{
#   image: torch.Tensor(shape=(3, 32, 96), dtype=torch.float32, device='cpu', requires_grad=False)
#   question: 'Is there a blue object?'
#   program: 'exists(Object, lambda x: blue(x))'
#   answer: False
# }
# train_dataset[i] = dict{
#   image: torch.Tensor(shape=(3, 32, 96), dtype=torch.float32, device='cpu', requires_grad=False)
#   question: 'Is there a circle?'
#   program: 'exists(Object, lambda x: circle(x))'
#   answer: True
# }
# train_dataset[i] = dict{
#   image: torch.Tensor(shape=(3, 32, 96), dtype=torch.float32, device='cpu', requires_grad=False)
#   question: 'Is there a red object?'
#   program: 'exists(Object, lambda x: red(x))'
#   answer: False
# }
# train_dataset[i] = dict{
#   image: torch.Tensor(shape=(3, 32, 96), dtype=torch.float32, device='cpu', requires_grad=False)
#   question: 'Is there a green object to the right of a rectangle?'
#   program: 'exists(Object, lambda x: exists(Object, lambda y: green(x) and right(x, y) and rectangle(y)))'
#   answer: False
# }
# train_dataset[i] = dict{
#   image: torch.Tensor(shape=(3, 32, 96), dtype=torch.float32, device='cpu', requires_grad=False)
#   question: 'Is there a blue object?'
#   program: 'exists(Object, lambda x: blue(x))'
#   answer: True
# }
# train_dataset[i] = dict{
#   image: torch.Tensor(shape=(3, 32, 96), dtype=torch.float32, device='cpu', requires_grad=False)
#   question: 'Is there a rectangle to the left of a green object?'
#   program: 'exists(Object, lambda x: exists(Object, lambda y: rectangle(x) and left(x, y) and green(y)))'
#   answer: False
# }

# %%
import matplotlib.pyplot as plt
